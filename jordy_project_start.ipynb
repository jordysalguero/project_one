# %%
import numpy as np
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import pandas as pd
import matplotlib.pyplot as plt
from function_creation import draw_chart,draw_chart2, print_label, calc_means, calc_sems, count_sample

# %%
#read, select, and rename the columns
df = pd.read_csv("employee_reviews.csv",encoding="utf-8")
#df=df[['Unnamed: 0','company', 'location','dates','job-title','overall-ratings','work-balance-stars','culture-values-stars','carrer-opportunities-stars','comp-benefit-stars','senior-mangemnet-stars']]
#df=df.rename(columns={'Unnamed: 0':'0','job-title':'title','overall-ratings':'overall', 'work-balance-stars':'wk_bal','culture-values-stars':'culture_val','carrer-opportunities-stars':'career_opp','comp-benefit-stars':'comp_benefit', 'senior-mangemnet-stars':'Sr_mgmt'})
df.head()
# Out:
#    Unnamed: 0 company           location          dates  \
# 0           1  google               none   Dec 11, 2018
# 1           2  google  Mountain View, CA   Jun 21, 2013
# 2           3  google       New York, NY   May 10, 2014
# 3           4  google  Mountain View, CA    Feb 8, 2015
# 4           5  google    Los Angeles, CA   Jul 19, 2018
#
#                                   job-title  \
# 0     Current Employee - Anonymous Employee
# 1         Former Employee - Program Manager
# 2  Current Employee - Software Engineer III
# 3     Current Employee - Anonymous Employee
# 4       Former Employee - Software Engineer
#
#                                              summary  \
# 0                           Best Company to work for
# 1  Moving at the speed of light, burn out is inev...
# 2  Great balance between big-company security and...
# 3  The best place I've worked and also the most d...
# 4                    Unique, one of a kind dream job
#
# ...

# %% [markdown]
# ##  Jordy DF for Word Cloud

# %%
#Google Word Cloud - PRO's
df_google =df.loc[df["company"] == "google"]
google_pros = []
google_cons = []
for index, row in df_google.iterrows():
    google_pros.append(row["pros"])
    google_cons.append(row["cons"])
    
google_pros_str = ' '.join(google_pros)
gptext = str(google_pros_str)

# Create the wordcloud object
gpwordcloud = WordCloud(width=1000, height=880, margin=0, max_font_size=100, max_words=50, background_color="white").generate(gptext)

# Display the generated image:
gpwc = plt.figure(1)
plt.imshow(gpwordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.title("Google Pro's")



#Google Word Cloud - CON'S
google_cons_str = ' '.join(google_cons)
gctext = str(google_cons_str)

# Create the wordcloud object
gcwordcloud = WordCloud(width=1000, height=880, margin=0, max_font_size=100, max_words=50, background_color="white").generate(gctext)

# Display the generated image:
gcwc = plt.figure(2)
plt.imshow(gcwordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.title("Google Con's")

plt.show()

# %%
#Amazon Word Cloud - PRO's
df_amazon =df.loc[df["company"] == "amazon"]
amazon_pros = []
amazon_cons = []
for index, row in df_amazon.iterrows():
    amazon_pros.append(row["pros"])
    amazon_cons.append(row["cons"])
    
amazon_pros_str = ' '.join(amazon_pros)
aptext = str(amazon_pros_str)

# Create the wordcloud object
apwordcloud = WordCloud(width=1000, height=880, margin=0, max_font_size=100, max_words=50, background_color="white").generate(aptext)

# Display the generated image:
apwc = plt.figure(1)
plt.imshow(apwordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.title("Amazon Pro's")


#Amazon Word Cloud - CON'S
amazon_cons_str = ' '.join(amazon_cons)
actext = str(amazon_cons_str)

# Create the wordcloud object
acwordcloud = WordCloud(width=1000, height=880, margin=0, max_font_size=100, max_words=50, background_color="white").generate(actext)

# Display the generated image:
acwc = plt.figure(2)
plt.imshow(acwordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.title("Amazon Con's")
# Out:
# Text(0.5, 1.0, "Amazon Con's")

# %%
#Facebook Word Cloud - PRO's
df_facebook =df.loc[df["company"] == "facebook"]
facebook_pros = []
facebook_cons = []
for index, row in df_facebook.iterrows():
    facebook_pros.append(row["pros"])
    facebook_cons.append(row["cons"])
    
facebook_pros_str = ' '.join(facebook_pros)
fptext = str(facebook_pros_str)

# Create the wordcloud object
fpwordcloud = WordCloud(width=1000, height=880, margin=0, max_font_size=100, max_words=50, background_color="white").generate(fptext)

# Display the generated image:
fpwc = plt.figure(1)
plt.imshow(fpwordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.title("Facebook Pro's")


#Facebook Word Cloud - CON'S
facebook_cons_str = ' '.join(facebook_cons)
fctext = str(facebook_cons_str)

# Create the wordcloud object
fcwordcloud = WordCloud(width=1000, height=880, margin=0, max_font_size=100, max_words=50, background_color="white").generate(fctext)

# Display the generated image:
fcwc = plt.figure(2)
plt.imshow(fcwordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.title("Facebook Con's")
# Out:
# Text(0.5, 1.0, "Facebook Con's")

# %%
#Netflix Word Cloud - PRO's
df_netflix =df.loc[df["company"] == "netflix"]
netflix_pros = []
netflix_cons = []
for index, row in df_netflix.iterrows():
    netflix_pros.append(row["pros"])
    netflix_cons.append(row["cons"])
    
netflix_pros_str = ' '.join(netflix_pros)
nptext = str(netflix_pros_str)

# Create the wordcloud object
npwordcloud = WordCloud(width=1000, height=880, margin=0, max_font_size=100, max_words=50, background_color="white").generate(nptext)

# Display the generated image:
npwc = plt.figure(1)
plt.imshow(npwordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.title("Netflix Pro's")


#Netflix Word Cloud - CON'S
netflix_cons_str = ' '.join(netflix_cons)
nctext = str(netflix_cons_str)

# Create the wordcloud object
ncwordcloud = WordCloud(width=1000, height=880, margin=0, max_font_size=100, max_words=50, background_color="white").generate(nctext)

# Display the generated image:
ncwc = plt.figure(2)
plt.imshow(ncwordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.title("Netflix Con's")
# Out:
# <img src="data:image/png;base64,..." width="639.3651084006071">
# <img src="data:image/png;base64,..." width="639.3651084006071">
# Text(0.5, 1.0, "Netflix Con's")

# %%
#Microsoft Word Cloud - PRO's
df_microsoft =df.loc[df["company"] == "microsoft"]
microsoft_pros = []
microsoft_cons = []
for index, row in df_microsoft.iterrows():
    microsoft_pros.append(row["pros"])
    microsoft_cons.append(row["cons"])
    
microsoft_pros_str = ' '.join(microsoft_pros)
mptext = str(microsoft_pros_str)

# Create the wordcloud object
mpwordcloud = WordCloud(width=1000, height=880, margin=0, max_font_size=100, max_words=50, background_color="white").generate(mptext)

# Display the generated image:
mpwc = plt.figure(1)
plt.imshow(mpwordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.title("Microsoft Pro's")


#Microsoft Word Cloud - CON'S
microsoft_cons_str = ' '.join(microsoft_cons)
mctext = str(microsoft_cons_str)

# Create the wordcloud object
mcwordcloud = WordCloud(width=1000, height=880, margin=0, max_font_size=100, max_words=50, background_color="white").generate(mctext)

# Display the generated image:
mcwc = plt.figure(2)
plt.imshow(mcwordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.title("Microsoft Con's")
# Out:
# Text(0.5, 1.0, "Microsoft Con's")

# %%
#Microsoft Word Cloud - PRO's
df_microsoft =df.loc[df["company"] == "microsoft"]
microsoft_pros = []
microsoft_cons = []
for index, row in df_microsoft.iterrows():
    microsoft_pros.append(row["pros"])
    microsoft_cons.append(row["cons"])
    
microsoft_pros_str = ' '.join(microsoft_pros)
mptext = str(microsoft_pros_str)

# Create the wordcloud object
mpwordcloud = WordCloud(width=1000, height=880, margin=0, max_font_size=100, max_words=50, background_color="white").generate(mptext)

# Display the generated image:
mpwc = plt.figure(1)
plt.imshow(mpwordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.title("Microsoft Pro's")


#Microsoft Word Cloud - CON'S
microsoft_cons_str = ' '.join(microsoft_cons)
mctext = str(microsoft_cons_str)

# Create the wordcloud object
mcwordcloud = WordCloud(width=1000, height=880, margin=0, max_font_size=100, max_words=50, background_color="white").generate(mctext)

# Display the generated image:
mcwc = plt.figure(2)
plt.imshow(mcwordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.title("Microsoft Con's")
# Out:
# Text(0.5, 1.0, "Microsoft Con's")

# %%
#Apple Word Cloud - PRO's
df_apple =df.loc[df["company"] == "apple"]
apple_pros = []
apple_cons = []
for index, row in df_apple.iterrows():
    apple_pros.append(row["pros"])
    apple_cons.append(row["cons"])
    
apple_pros_str = ' '.join(apple_pros)
apptext = str(apple_pros_str)

# Create the wordcloud object
appwordcloud = WordCloud(width=1000, height=880, margin=0, max_font_size=100, max_words=50, background_color="white").generate(apptext)

# Display the generated image:
appwc = plt.figure(1)
plt.imshow(appwordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.title("Apple Pro's")


#Apple Word Cloud - CON'S
apple_cons_str = ' '.join(apple_cons)
apctext = str(apple_cons_str)

# Create the wordcloud object
apcwordcloud = WordCloud(width=1000, height=880, margin=0, max_font_size=100, max_words=50, background_color="white").generate(apctext)

# Display the generated image:
apcwc = plt.figure(2)
plt.imshow(apcwordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.title("Apple Con's")
# Out:
# <img src="data:image/png;base64,..." width="639.3651084006071">
# <img src="data:image/png;base64,..." width="639.3651084006071">
# Text(0.5, 1.0, "Apple Con's")
